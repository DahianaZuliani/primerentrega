# %% [markdown]
# <a href="https://colab.research.google.com/github/DahianaZuliani/primerentrega/blob/main/Data_wrangling_%2B_Zuliani_Dahiana_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# VALORES DUPLICADOS

# %%
import numpy as np

# %%
import pandas as pd

# %%
pd.read_csv('Dataset 102023.csv')
# Out:
#       DATAFLOW  LAST UPDATE freq        SEXO  edad sizeclas  unit geo  \
# 0        ENERO            1    A    femenimo    20     GE10   100  AT
# 1     FEBRERO             2    B  masculino     25     GE10   120  AT
# 2        ENERO            1    C  masculino     26     GE10   140  AT
# 3     FEBRERO             2    B  masculino     30     GE10   160  AT
# 4        MARZO            3    C    femenimo    35     GE10   180  BE
# ..         ...          ...  ...         ...   ...      ...   ...  ..
# 141   FEBRERO             2    B  masculino     38    TOTAL   280  SK
# 142      ENERO            1    C    femenimo    45    TOTAL   300  UK
# 143   FEBRERO             2    A    femenimo    50    TOTAL   320  UK
# 144      MARZO            3    A  masculino     20    TOTAL   340  UK
# 145  NOVIEMBRE           11    B    femenimo    25    TOTAL   360  UK
#
#      TIME_PERIOD  OBS_VALUE    COMERCIAL PROBL COMER
# 0           2008        737          ADM   INFLACION
# ...

# %%
DF= pd.DataFrame({'Col 1':[0,1,2,2,3,3,6],
                  'SEXO': ['femenino','masculino','masculino','masculino','femenino','femenino','femenino'],
                  'PROBL COMER': ['INFLACION','DESEMPLEO','INFLACION','DESEMPLEO','INFLACION','INFLACION','INFLACION']})

# %%
DF.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# dtype: bool

# %%
DF.drop_duplicates()
# Out:
#    Col 1       SEXO PROBL COMER
# 0      0   femenino   INFLACION
# 1      1  masculino   DESEMPLEO
# 2      2  masculino   INFLACION
# 3      2  masculino   DESEMPLEO
# 4      3   femenino   INFLACION
# 6      6   femenino   INFLACION

# %%
DF.drop_duplicates(['SEXO'])
# Out:
#    Col 1       SEXO PROBL COMER
# 0      0   femenino   INFLACION
# 1      1  masculino   DESEMPLEO

# %% [markdown]
# CREAR SERIES MILTIINDEX

# %%
arrays = [np.array(["a", "a", "a", "b", "b", "b", "c", "c","c"]),
          np.array([1,2,3, 1,2,3, 1,2,3]),]
s = pd.Series(np.random.randn(9), index=arrays)
print(s)
# Out:
# a  1   -0.215297
#    2   -0.732336
#    3   -1.129972
# b  1   -1.745230
#    2    0.201428
#    3    0.279978
# c  1   -0.319610
#    2   -0.515683
#    3   -0.829597
# dtype: float64

# %%
s.index
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('a', 3),
#             ('b', 1),
#             ('b', 2),
#             ('b', 3),
#             ('c', 1),
#             ('c', 2),
#             ('c', 3)],
#            )

# %% [markdown]
# PRIMER NIVEL

# %%
s['a']
# Out:
# 1   -0.215297
# 2   -0.732336
# 3   -1.129972
# dtype: float64

# %% [markdown]
# SEGUNDO NIVEL

# %%
s.loc[:,2]
# Out:
# a   -0.732336
# b    0.201428
# c   -0.515683
# dtype: float64

# %%
s.unstack()
# Out:
#           1         2         3
# a -0.215297 -0.732336 -1.129972
# b -1.745230  0.201428  0.279978
# c -0.319610 -0.515683 -0.829597

# %%
s.sum(level=1)
# Out:
# <ipython-input-20-f9ea8fa8b215>:1: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   s.sum(level=1)
# 1   -2.280137
# 2   -1.046590
# 3   -1.679591
# dtype: float64

# %%
s.mean(level=0)
# Out:
# <ipython-input-21-0ca14a3b5a04>:1: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.median(level=1) should use df.groupby(level=1).median().
#   s.mean(level=0)
# a   -0.692535
# b   -0.421275
# c   -0.554963
# dtype: float64
